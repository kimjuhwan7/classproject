# %%
from matplotlib import font_manager,rc

font_path= '/Windows/Fonts/H2GTRE.TTF'
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
import requests
import bs4

url ='https://news.daum.net/'

res = requests.get(url)

#print(res.text)

soup = bs4.BeautifulSoup(res.text)
#print(soup)
data = soup.find_all('a')
#print(data)

# %%
category_url = {
    '메인' :['https://news.daum.net/'],
    '사회' :['https://news.daum.net/society'],
    '정치' :['https://news.daum.net/politics'],
    '경제' :['https://news.daum.net/economic'],
    '국제' :['https://news.daum.net/foreign'],
    '문화' :['https://news.daum.net/culture'],
    'IT' :['https://news.daum.net/digital']
}

# %%
for i ,j in category_url.items():
    res=requests.get(j[0])
    j.append(res.text)

# %%
#print(category_url['문화'])

# %%
temp = []

for i,j in category_url.items():
    soup = bs4.BeautifulSoup(j[1])
    
    for n in soup.find_all('span', attrs={'class':'info_cp'}):
        temp.append(n.text)
        
    for n in soup.find_all('span', attrs={'class': 'info_thumb'}):
        if n.find('a') == None:
            if '\n' in n.text.strip():
                temp.append(n.text.strip('\n')[0])
            elif n.text.strip() =='':
                temp.append(n.find('img',alt=True)['alt'])
            else:
                temp.append(n.text.strip())
print(temp)
# Out:
# ['정치', '사회', '정치', '국제', '정치', '사회', '사회', '사회', '사회', '정치', '사회', '경제', '경제', '사회', '정치', '경제', '국제', '국제', '정치', '경제', '머니투데이', '노컷뉴스', '서울신문', 'YTN', '뉴스1', '대구MBC', '서울신문', '미디어오늘', '뉴스1', '뉴스1', '강원도민일보', '조선비즈', '뉴스1', '헬스조선', '노컷뉴스', '연합뉴스', '경향신문', '연합뉴스', '뉴시스', '뉴시스', '국제신문', '전주MBC', '문화일보', '연합뉴스', 'YTN', '서울신문', 'YTN', '연합뉴스TV', 'MBC', 'KBS', '한겨레', '경향신문', 'SBS', '데일리안', 'YTN', '연합뉴스', '이데일리', '뉴시스', '한국일보', '한겨레', 'YTN', '연합뉴스', '뉴시스', '매일경제', '뉴스1', '데일리안', '뉴스1', 'MBC', '연합뉴스', '뉴스1', 'kbc광주방송', 'SBS', '시사IN', '오마이뉴스', '서울신문', 'MBN', 'KBS', '채널A', '헤럴드경제', '뉴시스', '뉴스1', '뉴시스', 'KBS', '뉴시스', '연합뉴스', '뉴시스', '이데일리', '뉴시스', '연합뉴스', '국제신문', '전주MBC', '헤럴드경제', '헤럴드경제', '아시아경제', '한국경제', 'SBS', 'JTBC', '헤럴드경제', '한국경제TV', '서울경제', 'SBS Biz', '프레시안', 'YTN', '연합뉴스', '한겨레', '아시아경제', '서울신문', '뉴스1', '뉴시스', '연합뉴스', '헤럴드경제', '헤럴드경제', '뉴시스', '연합뉴스', '연합뉴스', '연합뉴스', '한겨레', '한겨레', '조선일보', '서울신문', 'KBS', 'KBS', '서울신문', '뉴시스', '오마이뉴스', 'JTBC', 'SBS Biz', 'KBS', '뉴시스', 'MBN', '서울신문', '뉴시스', '연합뉴스', '뉴시스', '헬스조선', '강원도민일보', '프레시안', '한겨레21', '헤럴드경제', '문화일보', '더스쿠프', '헤럴드경제', '오마이뉴스', '여성동아', '키즈맘', '헬스조선', '코메디닷컴', '웨딩21뉴스', '여성동아', '메종', '투어코리아', '마리끌레르', 'JTBC', '대전일보', '조선일보', '경향신문', '경향신문', '대전일보', '경향신문', '세계일보', '디지털타임스', '연합뉴스', '연합뉴스', '비즈니스워치', '조선비즈', '뉴스1', '지디넷코리아', '지디넷코리아', '머니투데이', '아이뉴스24', '지디넷코리아', '헤럴드경제', '한겨레', '뉴시스', '뉴스1', '머니투데이', '뉴시스', '아이뉴스24', '한국경제', '조선비즈', '조선일보', '전자신문', '한국경제', '이데일리', '아이뉴스24', '전자신문']

# %%
print(category_url)
# Out:
# {'메인': ['https://news.daum.net/', '\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum 뉴스" />\n<meta property="og:site_name" content="다음뉴스" />\n<meta property="og:title" content="홈"/>\n<meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />\n<meta property="og:description" content="다음뉴스" />\n<meta property="og:url" content="https://news.daum.net/" />\n<link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">\n\n<title>홈 | 다음뉴스</title>\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/5c015e8/style.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/5c015e8/calendar.css.merged.css" />\n\n<!--[if lte IE 8]>\n<script src="https://m2.daumcdn.net/svc/original/U0301/cssjs/JSON-js/fc535e9cc8/json2.min.js"></script>\n<![endif]-->\n<!--[if lt IE 9]>\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/5c015e8/ie8.css.merged.css" />\n<![endif]-->\n\n<script src="//t1.daumcdn.net/media/kraken/news/5c015e8/common.merged.js"></script>\n\n<script type="text/javascript" src="https://t1.daumcdn.net/tiara/js/v1/tiara.min.js"></script>\n\n<script>\n  var ENV = {\n    Profile: {\n      isProduction: \'true\' || false,\n      isSandbox: \'\' || false,\n      isCbt: \'\' || false,\n    }\n  }\n</script>\n        <script src="//t1.daumcdn.net/media/kraken/news/5c015e8/homeMain.merged.js"></script>\n</head>\n<body>\n<div class="direct-link">\n    <!-- 웹접근성용 바로가기 링크 모음 -->\n    <a href="#mainContent">본문 바로가기</a>\n    <a href="#gnbContent">메뉴 바로가기</a>\n</div>\n\n<div class="container-doc">\n<header class="doc-header">\n    <!-- head_top -->\n    <div class="head_top">\n        <h1 class="doc-title">\n            <a href="https://www.daum.net/" class="link_daum" data-tiara-layer="gnb default logo">\n                <img src="//t1.daumcdn.net/media/common/newsview_2021/pc/rtn/logo_daum.png" width="44" height="18" class="logo_daum" alt="Daum">\n            </a>\n            <a href="https://news.daum.net/" id="kakaoServiceLogo" data-tiara-layer="GNB service news">\n                <span class="ir_wa">뉴스</span>\n            </a>\n        </h1>\n        <strong class="screen_out">관련 서비스</strong>\n        <ul class="doc-relate" data-tiara-layer="GNB service">\n            <li><a href="https://entertain.daum.net" class="link_services" data-tiara-layer="enter">연예</a></li>\n            <li><a href="https://sports.daum.net" class="link_services" data-tiara-layer="sports">스포츠</a></li>\n        </ul>\n\n<div id="wrapMinidaum"></div>\n<script type="text/javascript">\n\tvar minidaum_options = {\n\t\t// background 타입 지정 관련 옵션. default: white.\n\t\tbgType: "white", // white, dark, custom(no background)\n\n\t\t// logout 시 return url 변경 여부 flag : default: false - 다음탑으로 이동\n\t\tenableLogoutRetun: false, // false - 다음탑으로 이동, true - 현재페이지 혹은 returnUrl 값으로 이동\n\t\treturnUrl: \'\', // default - 현재페이지(window.location.href)\n\n\t\t// 실시간 이슈 사용 여부, default: false\n\t\tdisableHotissue: true, // false일 경우 사용, true일 경우 미사용\n\n\t\t// 로고 사용 여부, default: false\n\t\tdisableLogo: true, // false일 경우 사용, true일 경우 미사용\n\n\t\t// 티아라 사용 여부, default: false\n\t\tdisableTracker: false, // false일 경우 사용, true일 경우 미사용\n\n\t\t// 플래시에 의한 레이어 가림 현상 방지 사용 여부, default: false\n\t\tenableShield: false // false일 경우 미사용, true일 경우 사용\n\t}\n</script>\n<script src="https://go.daum.net/minidaum_pc.daum"></script>\n\n    </div> <!-- //head_top -->\n    <!-- gnb -->\n    <nav id="gnbContent" class="doc-gnb">\n        <div class="inner_gnb">\n            <h2 class="screen_out">뉴스 메인메뉴</h2>\n            <ul class="gnb_comm" data-tiara-layer="GNB tab">\n                <li class="on"><a href="/" class="link_gnb" data-tiara-lay ...

# %%
soup = bs4.BeautifulSoup(category_url['IT'][1])
for i in soup.find_all('span',attrs={'class':'info_thumb'}):
    if i.find('a')==None:
        print(i.text.strip())
# Out:
# 헤럴드경제
# 한겨레
# 뉴시스
# 뉴스1
# 머니투데이
# 뉴시스
# 아이뉴스24
# 한국경제
# 조선비즈
# 조선일보
# 전자신문
# 한국경제
# 이데일리
# 아이뉴스24
# 전자신문

# %%
for i,j in category_url.items():
    soup = bs4.BeautifulSoup(j[1])
    #언론사 리스트
    temp = []
    
    for n in soup.find_all('span', attrs={'class':'info_cp'}):
        temp.append(n.text)
        
    for n in soup.find_all('span', attrs={'class': 'info_thumb'}):
        if n.find('a') == None:
            if '\n' in n.text.strip():
                temp.append(n.text.strip('\n')[0])
            elif n.text.strip() =='':
                temp.append(n.find('img',alt=True)['alt'])
            else:
                temp.append(n.text.strip())
    j.append(temp)

# %%
print(category_url['IT'][5])
# Out:
# ['연합뉴스', '연합뉴스', '비즈니스워치', '조선비즈', '뉴스1', '지디넷코리아', '지디넷코리아', '머니투데이', '아이뉴스24', '지디넷코리아', '헤럴드경제', '한겨레', '뉴시스', '뉴스1', '머니투데이', '뉴시스', '아이뉴스24', '한국경제', '조선비즈', '조선일보', '전자신문', '한국경제', '이데일리', '아이뉴스24', '전자신문']

# %%
import wordcloud

text= ' '.join(category_url['IT'][5])
# print(text)
wc = wordcloud.WordCloud(font_path = font_path,background_color='white')
wc.generate_from_text(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
# 모든 언론사 리스트
data = []
for i, j in category_url.items():
    if i != '메인':
        data.extend(j[5])

unique_data = list(set(data))

print(unique_data)
# Out:
# ['대전일보', 'JTBC', '메종', '키즈맘', 'YTN', '조선비즈', '헤럴드경제', '헬스조선', '마리끌레르', '여성동아', '한겨레21', '아이뉴스24', '경향신문', '웨딩21뉴스', '뉴시스', '문화일보', '매일경제', '서울신문', '데일리안', '노컷뉴스', '한국경제', '뉴스1', '채널A', 'kbc광주방송', 'MBN', '한국일보', '프레시안', '더스쿠프', '머니투데이', '전주MBC', '오마이뉴스', '아시아경제', '비즈니스워치', 'MBC', '코메디닷컴', '투어코리아', '조선일보', '시사IN', 'SBS', '연합뉴스TV', '한국경제TV', '연합뉴스', '세계일보', '강원도민일보', '이데일리', 'SBS Biz', '지디넷코리아', '국제신문', '전자신문', '한겨레', '서울경제', 'KBS', '디지털타임스']

# %%
# 분야별 
rank  = {}
for i in unique_data:
    rank[i] = 0
for i in category_url['IT'][5]:
    rank[i] +=1
    
    
print(rank)
# Out:
# {'대전일보': 0, 'JTBC': 0, '메종': 0, '키즈맘': 0, 'YTN': 0, '조선비즈': 2, '헤럴드경제': 1, '헬스조선': 0, '마리끌레르': 0, '여성동아': 0, '한겨레21': 0, '아이뉴스24': 3, '경향신문': 0, '웨딩21뉴스': 0, '뉴시스': 2, '문화일보': 0, '매일경제': 0, '서울신문': 0, '데일리안': 0, '노컷뉴스': 0, '한국경제': 2, '뉴스1': 2, '채널A': 0, 'kbc광주방송': 0, 'MBN': 0, '한국일보': 0, '프레시안': 0, '더스쿠프': 0, '머니투데이': 2, '전주MBC': 0, '오마이뉴스': 0, '아시아경제': 0, '비즈니스워치': 1, 'MBC': 0, '코메디닷컴': 0, '투어코리아': 0, '조선일보': 1, '시사IN': 0, 'SBS': 0, '연합뉴스TV': 0, '한국경제TV': 0, '연합뉴스': 2, '세계일보': 0, '강원도민일보': 0, '이데일리': 1, 'SBS Biz': 0, '지디넷코리아': 3, '국제신문': 0, '전자신문': 2, '한겨레': 1, '서울경제': 0, 'KBS': 0, '디지털타임스': 0}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))

for i in category_url.keys() :
    rank = {}
    
    for j in unique_data :
        rank[j] = 0
    
    for j in category_url[i][5] :
        if i =='메인':
            continue
        rank[j] += 1
        
    x = rank.keys()
    y = rank.values()
    plt.bar(x,y,label=i)
    
plt.xticks(rotation=90)
plt.legend()
plt.title('분야별 언론사 랭킹')
plt.show()

# %%
# 전체 데이터 출력
print(data)
# Out:
# ['뉴스1', '뉴스1', '강원도민일보', '조선비즈', '뉴스1', '헬스조선', '노컷뉴스', '연합뉴스', '경향신문', '연합뉴스', '뉴시스', '뉴시스', '국제신문', '전주MBC', '문화일보', '연합뉴스', 'YTN', '서울신문', 'YTN', '연합뉴스TV', 'MBC', 'KBS', '한겨레', '경향신문', 'SBS', '데일리안', 'YTN', '연합뉴스', '이데일리', '뉴시스', '한국일보', '한겨레', 'YTN', '연합뉴스', '뉴시스', '매일경제', '뉴스1', '데일리안', '뉴스1', 'MBC', '연합뉴스', '뉴스1', 'kbc광주방송', 'SBS', '시사IN', '오마이뉴스', '서울신문', 'MBN', 'KBS', '채널A', '헤럴드경제', '뉴시스', '뉴스1', '뉴시스', 'KBS', '뉴시스', '연합뉴스', '뉴시스', '이데일리', '뉴시스', '연합뉴스', '국제신문', '전주MBC', '헤럴드경제', '헤럴드경제', '아시아경제', '한국경제', 'SBS', 'JTBC', '헤럴드경제', '한국경제TV', '서울경제', 'SBS Biz', '프레시안', 'YTN', '연합뉴스', '한겨레', '아시아경제', '서울신문', '뉴스1', '뉴시스', '연합뉴스', '헤럴드경제', '헤럴드경제', '뉴시스', '연합뉴스', '연합뉴스', '연합뉴스', '한겨레', '한겨레', '조선일보', '서울신문', 'KBS', 'KBS', '서울신문', '뉴시스', '오마이뉴스', 'JTBC', 'SBS Biz', 'KBS', '뉴시스', 'MBN', '서울신문', '뉴시스', '연합뉴스', '뉴시스', '헬스조선', '강원도민일보', '프레시안', '한겨레21', '헤럴드경제', '문화일보', '더스쿠프', '헤럴드경제', '오마이뉴스', '여성동아', '키즈맘', '헬스조선', '코메디닷컴', '웨딩21뉴스', '여성동아', '메종', '투어코리아', '마리끌레르', 'JTBC', '대전일보', '조선일보', '경향신문', '경향신문', '대전일보', '경향신문', '세계일보', '디지털타임스', '연합뉴스', '연합뉴스', '비즈니스워치', '조선비즈', '뉴스1', '지디넷코리아', '지디넷코리아', '머니투데이', '아이뉴스24', '지디넷코리아', '헤럴드경제', '한겨레', '뉴시스', '뉴스1', '머니투데이', '뉴시스', '아이뉴스24', '한국경제', '조선비즈', '조선일보', '전자신문', '한국경제', '이데일리', '아이뉴스24', '전자신문']

# %%
# 전체 랭킹

rank = {}
for i in data:
    if rank.get(i) == None:
        rank[i] = 1
    else:
        rank[i]+=1
        
print(rank)
# Out:
# {'뉴스1': 10, '강원도민일보': 2, '조선비즈': 3, '헬스조선': 3, '노컷뉴스': 1, '연합뉴스': 16, '경향신문': 5, '뉴시스': 17, '국제신문': 2, '전주MBC': 2, '문화일보': 2, 'YTN': 5, '서울신문': 6, '연합뉴스TV': 1, 'MBC': 2, 'KBS': 6, '한겨레': 6, 'SBS': 3, '데일리안': 2, '이데일리': 3, '한국일보': 1, '매일경제': 1, 'kbc광주방송': 1, '시사IN': 1, '오마이뉴스': 3, 'MBN': 2, '채널A': 1, '헤럴드경제': 9, '아시아경제': 2, '한국경제': 3, 'JTBC': 3, '한국경제TV': 1, '서울경제': 1, 'SBS Biz': 2, '프레시안': 2, '조선일보': 3, '한겨레21': 1, '더스쿠프': 1, '여성동아': 2, '키즈맘': 1, '코메디닷컴': 1, '웨딩21뉴스': 1, '메종': 1, '투어코리아': 1, '마리끌레르': 1, '대전일보': 2, '세계일보': 1, '디지털타임스': 1, '비즈니스워치': 1, '지디넷코리아': 3, '머니투데이': 2, '아이뉴스24': 3, '전자신문': 2}

# %%
plt.figure(figsize = (10,10))
x= rank.keys()
y=rank.values()

plt.bar(x,y)
plt.xticks(rotation=90)
plt.title('전체 분야 언론사 랭킹')
plt.show()

# %%
plt.figure(figsize = (10,10))
x= rank.keys()
y=rank.values()

plt.pie(y,labels=x)
plt.title('전체 분야 언론사 랭킹')
plt.show()
