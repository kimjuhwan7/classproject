# %%
# 쓰기
f= open('text.txt','w')
f.write('abcdefg')
f.close()

# %%
# 추가
f= open('text.txt','a')
f.write(',abcdefg1234124')
f.close()

# %%
# 읽기
f= open('text.txt','r')
data = f.read()
print(data)
# Out:
# abcdefg,abcdefg1234124,abcdefg1234124,abcdefg1234124,abcdefg1234124,abcdefg1234124

# %%
# csv
f= open('list.csv','r')
data = f.read()
f.close()
print(data)
print(type(data))
# Out:
# 이름,전화번호,등번호
# 손흥민,010-1111-2222,7
# 이강인,010-1111-2223,19
# 김민재,010-1111-2224,20
#
# <class 'str'>

# %%
import csv
# read : 행의 데이터-> list
f = open('list.csv','r')
data = csv.reader(f)
for i in data:
    print(i)
f.close()
# Out:
# ['이름', '전화번호', '등번호']
# ['손흥민', '010-1111-2222', '7']
# ['이강인', '010-1111-2223', '19']
# ['김민재', '010-1111-2224', '20']

# %%
import pandas as pd
data=pd.read_csv('list.csv',encoding='cp949')
print(data)
print(type(data))
# Out:
#     이름           전화번호  등번호
# 0  손흥민  010-1111-2222    7
# 1  이강인  010-1111-2223   19
# 2  김민재  010-1111-2224   20
# <class 'pandas.core.frame.DataFrame'>

# %%
#xls, xlsx 
import openpyxl as xl

data= xl.load_workbook('list.xlsx')
sheet = data['list']
print('>>>>',sheet)

for cell in sheet:
    for i in cell:
        print(i.value)
    print('---------')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2220\1890005154.py in <module>
#       2 import openpyxl as xl
#       3
# ----> 4 data= xl.load_workbook('list.xlsx')
#       5 sheet = data['list']
#       6 print('>>>>',sheet)
#
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\reader\excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     315     reader = ExcelReader(filename, read_only, keep_vba,
#     316                         data_only, keep_links)
# --> 317     reader.read()
#     318     return reader.wb
#
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\reader\excel.py in read(self)
#     279         self.read_properties()
#     280         self.read_theme()
# --> 281         apply_stylesheet(self.archive, self.wb)
#     282         self.read_worksheets()
# ...

# %%
data=['a','b','c']
f=open('oickle_data.txt','wb')
pickle.dump(data,f)
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2220\3740366955.py in <module>
#       1 data=['a','b','c']
#       2 f=open('oickle_data.txt','wb')
# ----> 3 pickle.dump(data,f)
#       4 f.close()
#
# NameError: name 'pickle' is not defined

# %%
import requests

url ='https://www.naver.com'
req = requests.get(url)
print(req)
# Out:
# <Response [200]>

# %%
print(req.text)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...

# %%
#print(res.text)
print(type(req.text))
# Out:
# <class 'str'>

# %%
print(req.text.find('네이버'))
# Out:
# 365

# %%
import bs4

# %%
import selenium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2220\1698891545.py in <module>
# ----> 1 import selenium
#
# ModuleNotFoundError: No module named 'selenium'

# %%
import bs4
data ="<div>안녕하세요</div>"
soup = bs4.BeautifulSoup(data)
print(soup)
# Out:
# <html><body><div>안녕하세요</div></body></html>

# %%
# find : 특정 선택자를 통해서 해당 엘리먼트를 검색=> 반환
print(soup.find('div'))
print(soup.find('div').text)
# Out:
# <div>안녕하세요</div>
# 안녕하세요

# %%
import requests
import bs4

url ='https://www.naver.com'
req = requests.get(url)
print(req)

soup = bs4.BeautifulSoup(requests.get(url).text)
find_data = soup.find('a', attrs={'class':'issue'}).text
# Out:
# <Response [200]>
